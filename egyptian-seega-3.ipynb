# %%
from game3.jwalker import *
w = W.new()
# Out:
# Final pattern((1, 1, 0, 2, 2, 2, 0, 1, 0), 1)
# Final pattern((1, 2, 1, 0, 2, 0, 1, 2, 0), 1)
# Final pattern((1, 2, 1, 0, 2, 0, 0, 2, 1), 1)
# Final pattern((1, 2, 0, 0, 1, 2, 0, 2, 1), 2)
# Final pattern((2, 0, 1, 2, 1, 0, 1, 0, 2), 2)
# Final pattern((2, 0, 1, 2, 1, 0, 2, 0, 1), 1)
# Final pattern((2, 0, 1, 0, 2, 0, 1, 1, 2), 1)
# Final pattern((2, 2, 1, 0, 2, 1, 0, 0, 1), 2)
# Final pattern((2, 2, 1, 0, 1, 0, 1, 2, 0), 2)
# Final pattern((2, 2, 0, 1, 1, 1, 0, 2, 0), 2)
# Final pattern((2, 0, 0, 1, 2, 0, 1, 1, 2), 1)
# Final pattern((2, 0, 2, 1, 1, 1, 0, 2, 0), 2)
# Final pattern((2, 2, 2, 1, 1, 0, 0, 0, 1), 1)
# Final pattern((2, 0, 1, 1, 2, 1, 0, 0, 2), 1)
# Final pattern((2, 0, 1, 1, 2, 0, 0, 1, 2), 1)
# Final pattern((0, 2, 1, 1, 2, 0, 0, 2, 1), 1)
# Final pattern((0, 2, 1, 1, 2, 0, 1, 2, 0), 1)
# Final pattern((0, 2, 1, 0, 1, 2, 1, 2, 0), 2)
# Final pattern((1, 0, 1, 2, 2, 2, 0, 1, 0), 1)
# Final pattern((1, 0, 0, 2, 1, 0, 2, 2, 1), 2)
# ...

# %%
w.t.pc
# Out:
# <div float="left"><table><caption>Current</caption><tr><td>O</td><td>O</td><td>O</td></tr><tr><td></td><td></td><td></td></tr><tr><td>X</td><td>X</td><td>X</td></tr><table>turn: O, f: {(1, 'start')}, n: 7</div>

# %%
w.print_next_boards()
# Out:
# <div float="left"><table><caption>Case 0</caption><tr><td></td><td>O</td><td>O</td></tr><tr><td>O</td><td></td><td></td></tr><tr><td>X</td><td>X</td><td>X</td></tr><table>turn: X, f: set(), n: 5</div><div float="left"><table><caption>Case 1</caption><tr><td></td><td>O</td><td>O</td></tr><tr><td></td><td>O</td><td></td></tr><tr><td>X</td><td>X</td><td>X</td></tr><table>turn: X, f: set(), n: 4</div><div float="left"><table><caption>Case 2</caption><tr><td>O</td><td></td><td>O</td></tr><tr><td>O</td><td></td><td></td></tr><tr><td>X</td><td>X</td><td>X</td></tr><table>turn: X, f: set(), n: 5</div><div float="left"><table><caption>Case 3</caption><tr><td>O</td><td></td><td>O</td></tr><tr><td></td><td>O</td><td></td></tr><tr><td>X</td><td>X</td><td>X</td></tr><table>turn: X, f: set(), n: 4</div><div float="left"><table><caption>Case 4</caption><tr><td>O</td><td></td><td>O</td></tr><tr><td></td><td></td><td>O</td></tr><tr><td>X</td><td>X</td><td>X</td></tr><table>turn: X, f: set(), n: 5</di
# ...

# %%
w.f(6)

# %%
w.pc
# Out:
# <div float="left"><table><caption>Current</caption><tr><td>O</td><td>O</td><td></td></tr><tr><td></td><td></td><td>O</td></tr><tr><td>X</td><td>X</td><td>X</td></tr><table>turn: X, f: set(), n: 5</div>

# %%
w.pn
# Out:
# <div float="left"><table><caption>Case 0</caption><tr><td>O</td><td>O</td><td></td></tr><tr><td>X</td><td></td><td>O</td></tr><tr><td></td><td>X</td><td>X</td></tr><table>turn: O, f: {(1, 'win')}, n: 5</div><div float="left"><table><caption>Case 1</caption><tr><td>O</td><td>O</td><td></td></tr><tr><td></td><td>X</td><td>O</td></tr><tr><td></td><td>X</td><td>X</td></tr><table>turn: O, f: set(), n: 4</div><div float="left"><table><caption>Case 2</caption><tr><td>O</td><td>O</td><td></td></tr><tr><td>X</td><td></td><td>O</td></tr><tr><td>X</td><td></td><td>X</td></tr><table>turn: O, f: {(1, 'win')}, n: 6</div><div float="left"><table><caption>Case 3</caption><tr><td>O</td><td>O</td><td></td></tr><tr><td></td><td>X</td><td>O</td></tr><tr><td>X</td><td></td><td>X</td></tr><table>turn: O, f: set(), n: 5</div><div float="left"><table><caption>Case 4</caption><tr><td>O</td><td>O</td><td></td></tr><tr><td></td><td>X</td><td>O</td></tr><tr><td>X</td><td>X</td><td></td></tr><table>turn: O, f: s
# ...
